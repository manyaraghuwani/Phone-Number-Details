# %%
pip install phonenumbers
# Out:
# Requirement already satisfied: phonenumbers in c:\users\admin\anaconda3\lib\site-packages (8.13.27)Note: you may need to restart the kernel to use updated packages.

# %%
import phonenumbers
from phonenumbers import timezone,geocoder,carrier
mobile=input("enter the no. with +__")
phone=phonenumbers.parse(mobile)
time=timezone.time_zones_for_number(phone)#it gives timezone
carrier=carrier.name_for_number(phone,"en")#carrier is used to find operator(company)
reg=geocoder.description_for_number(phone,"en")#geocoder is used for location
print(phone)
print(time)
print(carrier)
print(reg)
#en- this used to get output in english
# Out:
# enter the no. with +__+918619005685
# Country Code: 91 National Number: 8619005685
# ('Asia/Calcutta',)
# Reliance Jio
# India
